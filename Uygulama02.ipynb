# %%
import requests
#http request
response = requests.get('https://erdincuzun.com/bilgi_erisimi/bilgi-erisimi-ve-web-aramasi-dersi/')

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.content) #türkçe karakter sorunu
# Out:
# b'<!doctype html>\n<html lang="tr">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<title>Bilgi Eri\xc5\x9fimi ve Web Aramas\xc4\xb1 Dersi - Erdin\xc3\xa7 Uzun</title>\n\n<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n<link rel="canonical" href="https://erdincuzun.com/bilgi_erisimi/bilgi-erisimi-ve-web-aramasi-dersi/" />\n<meta property="og:locale" content="tr_TR" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Bilgi Eri\xc5\x9fimi ve Web Aramas\xc4\xb1 Dersi - Erdin\xc3\xa7 Uzun" />\n<meta property="og:description" content="Bu ders, \xc3\xa7al\xc4\xb1\xc5\x9fma alan\xc4\xb1m olan Bilgi Eri\xc5\x9fimi (Information Retrieval) ve Web Aramas\xc4\xb1 (Web Searching) konular\xc4\xb1 \xc3\xbczerinedir. Ders, bir\xc3\xa7ok \xc3\xbcniversitede master d\xc3\xbczeyinde okutulmaktad\xc4\xb1r. Bilgi eri
# ...

# %%
response.text #türkçe karakterler sorunsuz
# Out:
# '<!doctype html>\n<html lang="tr">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<title>Bilgi Erişimi ve Web Araması Dersi - Erdinç Uzun</title>\n\n<meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n<link rel="canonical" href="https://erdincuzun.com/bilgi_erisimi/bilgi-erisimi-ve-web-aramasi-dersi/" />\n<meta property="og:locale" content="tr_TR" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Bilgi Erişimi ve Web Araması Dersi - Erdinç Uzun" />\n<meta property="og:description" content="Bu ders, çalışma alanım olan Bilgi Erişimi (Information Retrieval) ve Web Araması (Web Searching) konuları üzerinedir. Ders, birçok üniversitede master düzeyinde okutulmaktadır. Bilgi erişimi, bir kullanıcının belirli bir konudaki metin tabanlı sorgusuna yanıt verme işlemidir. Web araması, dünyanın en büyük metin
# ...
